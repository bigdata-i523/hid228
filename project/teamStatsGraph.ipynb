# %%
import csv

# %%
import matplotlib.pylab as plt

# %%
import numpy as np

# %%
import csv

# %%
so_data = []

# %%
with open('impacts.csv', 'r') as csvfile:
    so = csv.reader(csvfile, delimiter=',')

    for row in so:
        so_data.append(row)

# %%
len=len(so_data)

# %%
teamstats=so_data[0][1:]

# %%
for i in range(1,len):
    print(so_data[i][1:])
    nparray=np.array(list(map(float,so_data[i][1:])))
   # plt.yticks(np.arange(nparray.min(), nparray.max()))
    plt.plot(teamstats,nparray)
# Out:
# ['0.196740639', '0.210292992', '0.211735165', '0.208351478', '0.138950544', '0.169867851', '0.111721053', '0.086824372', '0.153333333']
# ['0.225523492', '0.153556855', '0.07649606', '0.220790305', '0.353808671', '0.16195323', '0.442853244', '0.307392135', '0.667619048']
# ['0.155320121', '0.324511978', '0.177823473', '0.10465245', '0.103174773', '0.273294323', '0.152664724', '0.365450153', '0.085396825']
# ['0.422415749', '0.311638175', '0.533945302', '0.466205766', '0.404066012', '0.394884595', '0.292760979', '0.240333341', '0.093650794']

# %%
plt.show()
